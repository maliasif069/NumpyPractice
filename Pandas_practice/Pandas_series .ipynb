# %% [markdown]
# ### What is Pandas
#
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language.
#
# https://pandas.pydata.org/about/index.html

# %% [markdown]
# ### Pandas Series
#
# A Pandas Series is like a column in a table. It is a 1-D array holding data of any type.

# %% [markdown]
# ### Importing Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Series from lists

# %%
# string
country = ['India','Pakistan','USA','Nepal','Srilanka']

pd.Series(country)
# Out:
# 0       India
# 1    Pakistan
# 2         USA
# 3       Nepal
# 4    Srilanka
# dtype: object

# %%
# integers
runs = [13,24,56,78,100]

runs_ser = pd.Series(runs)

# %%
# custom index
marks = [67,57,89,100]
subjects = ['maths','english','science','hindi']

pd.Series(marks,index=subjects)
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
# setting a name
marks = pd.Series(marks,index=subjects,name='Nitish ke marks')
marks
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: Nitish ke marks, dtype: int64

# %% [markdown]
# ### Series from dict

# %%
marks = {
    'maths':67,
    'english':57,
    'science':89,
    'hindi':100
}

marks_series = pd.Series(marks,name='nitish ke marks')
marks_series
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: nitish ke marks, dtype: int64

# %% [markdown]
# ### Series Attributes

# %%
# size
marks_series.size
# Out:
# 4

# %%
# dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
# name
marks_series.name
# Out:
# 'nitish ke marks'

# %%
# is_unique
marks_series.is_unique

pd.Series([1,1,2,3,4,5]).is_unique
# Out:
# False

# %%
# index
marks_series.index
# Out:
# Index(['maths', 'english', 'science', 'hindi'], dtype='object')

# %%
runs_ser.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# values
marks_series.values
# Out:
# array([ 67,  57,  89, 100])

# %% [markdown]
# ### Series using read_csv

# %%
# with one col
subs = pd.read_csv('/content/subs.csv').squeeze('columns')
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# with 2 cols
vk = pd.read_csv('/content/kohli_ipl.csv',index_col='match_no',squeeze=True)
vk

# %%
movies = pd.read_csv('/content/bollywood.csv',index_col='movie',squeeze=True)
movies

# %% [markdown]
# ### Series methods

# %%
# head and tail
subs.head()

# %%
vk.head(3)

# %%
vk.tail(10)

# %%
# sample
movies.sample(5)

# %%
# value_counts -> movies
movies.value_counts()

# %%
# sort_values -> inplace
vk.sort_values(ascending=False).head(1).values[0]

# %%
vk.sort_values(ascending=False)

# %%
# sort_index -> inplace -> movies
movies.sort_index(ascending=False,inplace=True)

# %%
movies

# %%
vk.sort_values(inplace=True)

# %%
vk

# %% [markdown]
# ### Series Maths Methods

# %%
# count
vk.count()

# %%
# sum -> product
bollywood.sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14105/3859318657.py in <cell line: 0>()
#       1 # sum -> product
# ----> 2 bollywood.sum()
#
# NameError: name 'bollywood' is not defined

# %%
# mean -> median -> mode -> std -> var
subs.mean()
print(vk.median())
print(movies.mode())
print(subs.std())
print(vk.var())

# %%
# min/max
subs.max()

# %%
# describe
subs.describe()

# %% [markdown]
# ### Series Indexing

# %%
# integer indexing
x = pd.Series([12,13,14,35,46,57,58,79,9])
x

# %%
# negative indexing
x[-1]

# %%
movies

# %%
vk[-1]

# %%
marks_series[-1]

# %%
# slicing
vk[5:16]

# %%
# negative slicing
vk[-5:]

# %%
movies[::2]

# %%
# fancy indexing
vk[[1,3,4,5]]

# %%
# indexing with labels -> fancy indexing
movies['2 States (2014 film)']

# %% [markdown]
# ### Editing Series

# %%
# using indexing
marks_series[1] = 100
marks_series
# Out:
# /tmp/ipykernel_14105/3621369324.py:2: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_series[1] = 100
# maths       67
# english    100
# science     89
# hindi      100
# Name: nitish ke marks, dtype: int64

# %%
# what if an index does not exist
marks_series['evs'] = 100

# %%
marks_series
# Out:
# maths       67
# english    100
# science     89
# hindi      100
# evs        100
# Name: nitish ke marks, dtype: int64

# %%
# slicing
runs_ser[2:4] = [100,100]
runs_ser
# Out:
# 0     13
# 1     24
# 2    100
# 3    100
# 4    100
# dtype: int64

# %%
# fancy indexing
runs_ser[[0,3,4]] = [0,0,0]
runs_ser
# Out:
# 0      0
# 1     24
# 2    100
# 3      0
# 4      0
# dtype: int64

# %%
# using index label
movies['2 States (2014 film)'] = 'Alia Bhatt'
movies
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14105/1601538050.py in <cell line: 0>()
#       1 # using index label
# ----> 2 movies['2 States (2014 film)'] = 'Alia Bhatt'
#       3 movies
#
# NameError: name 'movies' is not defined

# %% [markdown]
# ### Copy and Views

# %% [markdown]
# ### Series with Python Functionalities

# %%
# len/type/dir/sorted/max/min
print(len(subs))
print(type(subs))
print(dir(subs))
print(sorted(subs))
print(min(subs))
print(max(subs))

# %%
# type conversion
list(marks_series)

# %%
dict(marks_series)

# %%
# membership operator

'2 States (2014 film)' in movies

# %%
'Alia Bhatt' in movies.values

# %%
movies

# %%
# looping
for i in movies.index:
  print(i)

# %%
# Arithmetic Operators(Broadcasting)
100 + marks_series

# %%
# Relational Operators

vk >= 50

# %% [markdown]
# ### Boolean Indexing on Series

# %%
# Find no of 50's and 100's scored by kohli
vk[vk >= 50].size

# %%
# find number of ducks
vk[vk == 0].size
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14105/2997475273.py in <cell line: 0>()
#       1 # find number of ducks
# ----> 2 vk[vk == 0].size
#
# NameError: name 'vk' is not defined

# %%
# Count number of day when I had more than 200 subs a day
subs[subs > 200].size

# %%
# find actors who have done more than 20 movies
num_movies = movies.value_counts()
num_movies[num_movies > 20]

# %% [markdown]
# ### Plotting Graphs on Series

# %%
subs.plot()

# %%
movies.value_counts().head(20).plot(kind='pie')

# %% [markdown]
# ### Some Important Series Methods

# %%
# astype
# between
# clip
# drop_duplicates
# isnull
# dropna
# fillna
# isin
# apply
# copy

# %%
import numpy as np
import pandas as pd

# %%
subs = pd.read_csv('/content/subs.csv',squeeze=True)
subs

# %%
vk = pd.read_csv('/content/kohli_ipl.csv',index_col='match_no',squeeze=True)
vk

# %%
movies = pd.read_csv('/content/bollywood.csv',index_col='movie',squeeze=True)
movies

# %%
# astype
import sys
sys.getsizeof(vk)

# %%
sys.getsizeof(vk.astype('int16'))

# %%
# between
vk[vk.between(51,99)].size

# %%
# clip
subs

# %%
subs.clip(100,200)

# %%
# drop_duplicates
temp = pd.Series([1,1,2,2,3,3,4,4])
temp

# %%
temp.drop_duplicates(keep='last')

# %%
temp.duplicated().sum()

# %%
vk.duplicated().sum()

# %%
movies.drop_duplicates()

# %%
temp = pd.Series([1,2,3,np.nan,5,6,np.nan,8,np.nan,10])
temp

# %%
temp.size

# %%
temp.count()

# %%
# isnull
temp.isnull().sum()

# %%
# dropna
temp.dropna()

# %%
# fillna
temp.fillna(temp.mean())

# %%
# isin
vk[(vk == 49) | (vk == 99)]

# %%
vk[vk.isin([49,99])]

# %%
# apply
movies

# %%
movies.apply(lambda x:x.split()[0].upper())

# %%
subs

# %%
subs.apply(lambda x:'good day' if x > subs.mean() else 'bad day')

# %%
subs.mean()

# %%
# copy

# %%
vk

# %%
new = vk.head()

# %%
new

# %%
new[1] = 1

# %%
new = vk.head().copy()

# %%
new[1] = 100

# %%
new
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14105/1886468072.py in <cell line: 0>()
# ----> 1 new
#
# NameError: name 'new' is not defined

# %%
vk
